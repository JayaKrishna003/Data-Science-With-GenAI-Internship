# %%
# 1.Defanging an IP Address

class Solution(object):
    def defangIPaddr(self, address):
        return address.replace(".",'[.]')    

A = Solution()
print(A.defangIPaddr("1.1.1.1"))
# Out:
# 1[.]1[.]1[.]1

# %%
# 2.Find Numbers with Even Number of Digits

class Solution:
    def findNumbers(self, nums):
        count = 0
        for num in nums:
            if len(str(num)) % 2 == 0:
                count += 1
        return count    
nums1 = [12, 345, 2, 6, 7896]
print("find even digit numbers:", find_even_digit_numbers(nums1))
# Out:
# find even digit numbers: 2

# %%
# 3.Number of Good Pairs
class Solution:
    def numIdenticalPairs(self, nums):
        freq = {}
        good_pairs = 0
        for num in nums:
            if num in freq:
                good_pairs += freq[num]
                freq[num] += 1
            else:
                freq[num] = 1
        return good_pairs
nums1 = [1, 2, 3, 1, 1, 3]
print("number of good pairs:", number_of_good_pairs(nums1))
# Out:
# number of good pairs: 4

# %%
# 4.How Many Numbers Are Smaller Than the Current Number

class Solution:
    def smallerNumbersThanCurrent(self, nums):
        count = [0] * 101  
        for num in nums:
            count[num] += 1
        for i in range(1, 101):
            count[i] += count[i - 1]
        result = []
        for num in nums:
            result.append(count[num - 1] if num > 0 else 0)
        return result
nums1 = [8, 1, 2, 2, 3]

sol = Solution() 
print(sol.smallerNumbersThanCurrent(nums1))
# Out:
# [4, 0, 1, 1, 3]

# %%
# 5.Subtract the Product and Sum of Digits of an Integer

class Solution:
    def subtractProductAndSum(self, n: int):
        product = 1
        summation = 0

        while n > 0:
            digit = n % 10
            product *= digit
            summation += digit
            n //= 10

        return product - summation
nums = [234, 4421, 1000]
sol = Solution()
print(f"{sol.subtractProductAndSum(n)}\n")
# Out:
# 15

# %%
# 6.XOR Operation in an Array

class Solution:
    def xorOperation(self, n: int, start):
        result = 0
        for i in range(n):
            result ^= start + 2 * i
        return result
F = Solution()
print(F.xorOperation(5,0))
# Out:
# 8
